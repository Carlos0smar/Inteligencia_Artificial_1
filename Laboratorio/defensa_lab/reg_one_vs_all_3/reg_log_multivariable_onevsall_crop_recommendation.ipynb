# %% [markdown]
# # Clasificación multiclase
#
# ## Introduction
#
# En este ejercicio se implementa la regresion one-vs-all y una red neuronal para reconocimiento de digitos.
#
# Antes de empezar la ejecución de las partes de codigo correspondienters a los ejercicios, se requiere importar todas las librerias necesarias.

# %%
# utilizado para la manipulación de directorios y rutas
import os

# Cálculo científico y vectorial para python
import numpy as np

# Libreria para graficos
from matplotlib import pyplot

# Modulo de optimizacion en scipy
from scipy import optimize

# modulo para cargar archivos en formato MATLAB
from scipy.io import loadmat

import pandas as pd

# le dice a matplotlib que incruste gráficos en el cuaderno
# %matplotlib inline

# %%
'''Infromación del DATASET

VARIABLES INDEPENDIENTES:

# obj_ID = Object Identifier, the unique value that identifies the object in the image catalog used by the CAS
# alpha = Right Ascension angle (at J2000 epoch)
# delta = Declination angle (at J2000 epoch)
u = Ultraviolet filter in the photometric system
g = Green filter in the photometric system
r = Red filter in the photometric system
i = Near Infrared filter in the photometric system
z = Infrared filter in the photometric system
# run_ID = Run Number used to identify the specific scan
# rerun_ID = Rerun Number to specify how the image was processed
cam_col = Camera column to identify the scanline within the run
# field_ID = Field number to identify each field
# spec_obj_ID = Unique ID used for optical spectroscopic objects (this means that 2 different observations with the same spec_obj_ID must share the output class)
redshift = redshift value based on the increase in wavelength
plate = plate ID, identifies each plate in SDSS
MJD = Modified Julian Date, used to indicate when a given piece of SDSS data was taken
# fiber_ID = fiber ID that identifies the fiber that pointed the light at the focal plane in each observation

VARIABLE DEPENDIENTE:

class = object class (galaxy, star or quasar object)
'''
# Out:
# 'Infromación del DATASET\n\nVARIABLES INDEPENDIENTES:\n\n# obj_ID = Object Identifier, the unique value that identifies the object in the image catalog used by the CAS\n# alpha = Right Ascension angle (at J2000 epoch)\n# delta = Declination angle (at J2000 epoch)\nu = Ultraviolet filter in the photometric system\ng = Green filter in the photometric system\nr = Red filter in the photometric system\ni = Near Infrared filter in the photometric system\nz = Infrared filter in the photometric system\n# run_ID = Run Number used to identify the specific scan\n# rerun_ID = Rerun Number to specify how the image was processed\ncam_col = Camera column to identify the scanline within the run\n# field_ID = Field number to identify each field\n# spec_obj_ID = Unique ID used for optical spectroscopic objects (this means that 2 different observations with the same spec_obj_ID must share the output class)\nredshift = redshift value based on the increase in wavelength\nplate = plate ID, identifies each plate in SDSS\nMJD = Modified Julian Date, used to indicate when a given piece of SDSS data was taken\n# fiber_ID = fiber ID that identifies the fiber that pointed the light at the focal plane in each observation\n\nVARIABLE DEPENDIENTE:\n\nclass = object class (galaxy, star or quasar object)\n'

# %%
''' Recuperación y Limpieza de datos'''

loadData = pd.read_csv('crop_recommendation.csv')

''' SIRVE PARA CONVERTIR LOS CATOS A MINUSCULAS '''
# loadData['is_genuine'] = loadData['is_genuine'].str.lower()

'''PARA VERIFICAR DE QUE TIPO SON LOS DATOS (STRIGN, FLOAT, INT, ETC)'''
# print(loadData['is_genuine'].dtype)

'''MAPEO DE DATOS'''
mapeo_genuine = {'rice': 1, 'maize': 2 ,'chickpea': 3 ,'kidneybeans': 4 ,'pigeonpeas': 5 ,'mothbeans': 6,
 'mungbean': 7, 'blackgram': 8, 'lentil': 9, 'pomegranate': 10, 'banana': 11, 'mango': 12, 'grapes': 13,
 'watermelon': 14, 'muskmelon':15, 'apple':16, 'orange': 17, 'papaya':18, 'coconut': 19, 'cotton': 20,
 'jute': 21, 'coffee': 22}
loadData['label'] = loadData['label'].map(mapeo_genuine)


'''RELLENAR CON LA MEDIA ESPACIOS VACIOS'''
# median_margin_up = loadData['margin_up'].median()
# filled_data = loadData.fillna({'margin_up': median_margin_up})

'''ELIMINAR FILAS CON DATOS VACIOS'''
# num_column= loadData.shape[1]
# cleanData = loadData[loadData.columns].dropna(thresh=num_column)


# PARA VERIFICAR QUE LOS DATOS SEAN UNICOS (muestra los datos encontrados en este caso, false y true)
# print(loadData['label'].unique())


# PARA ELIMINAR LAS COLUMNAS INNECESARIAS
# column_innecesary = ['obj_ID', 'alpha', 'delta', 'run_ID', 'rerun_ID', 'field_ID', 'spec_obj_ID', 'fiber_ID']
# cleanData = loadData.drop(column_innecesary, axis=1)


loadData.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536      1
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537      1
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248      1
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034      1
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340      1

# %%
'''Sirve para determinar la cantidad de filas dependiendo de cada elemento único'''

# elementos_unicos = loadData['label'].unique()

# # Calcula la cantidad de filas para cada elemento único
# cantidad_filas_por_elemento = loadData['label'].value_counts()

# # Imprime los elementos únicos y su cantidad de filas correspondiente
# for elemento in elementos_unicos:
#     cantidad_filas = cantidad_filas_por_elemento[elemento]
#     print(f"Elemento: {elemento}, Cantidad de filas: {cantidad_filas}")



Cant_unico_valores = loadData['label'].value_counts()
print(Cant_unico_valores)
# Out:
# label
# 1     100
# 2     100
# 21    100
# 20    100
# 19    100
# 18    100
# 17    100
# 16    100
# 15    100
# 14    100
# 13    100
# 12    100
# 11    100
# 10    100
# 9     100
# 8     100
# 7     100
# 6     100
# 5     100
# 4     100
# 3     100
# 22    100
# Name: count, dtype: int64

# %% [markdown]
# ## 1 Clasificación multiclase
#
# Para este ejercicio, se usará regresión logística y redes neuronales para reconocer dígitos escritos a mano (de 0 a 9). El reconocimiento automático de dígitos escritos a mano se usa ampliamente en la actualidad, desde el reconocimiento de códigos postales (códigos postales) en sobres de correo hasta el reconocimiento de montos escritos en cheques bancarios. Este ejercicio  mostrará cómo los métodos que ha aprendido se pueden utilizar para esta tarea de clasificación.
#
# La primera parte del ejercicio, extenderá la implementación anterior de la regresión logística y la aplicará a la clasificación de uno contra todos (one vs all).
#
# ### 1.1 Dataset
#
# Se proporciona un conjunto de datos en `ex3data1.mat` que contiene 5000 ejemplos de entrenamiento de dígitos escritos a mano (este es un subconjunto del conjunto de datos de dígitos escritos a mano [MNIST] http://yann.lecun.com/exdb/mnist)). El formato `.mat` significa que los datos se han guardado en un formato de matriz nativo Octave/MATLAB, en lugar de un formato de texto (ASCII) como un archivo csv. Usamos el formato `.mat` aquí para mostrar los diferentes formatos en los que se pueden presentar los datasets. Python proporciona mecanismos para cargar el formato nativo de MATLAB usando la función `loadmat` dentro del módulo` scipy.io`. Esta función devuelve un diccionario de Python con claves que contienen los nombres de las variables dentro del archivo `.mat`.
#
# Hay 5000 ejemplos de entrenamiento en `ex3data1.mat`, donde cada ejemplo de entrenamiento es una imagen en escala de grises de 20 píxeles por 20 píxeles del dígito. Cada píxel está representado por un número de punto flotante que indica la intensidad de la escala de grises en esa ubicación. La cuadrícula de 20 por 20 píxeles se "desenrolla" en un vector de 400 dimensiones. Cada uno de estos ejemplos de entrenamiento se convierte en una sola fila en nuestra matriz de datos "X". Esto da una matriz `X` de 5000 por 400 donde cada fila es un ejemplo de entrenamiento para una imagen de dígitos escrita a mano.
#
# $$ X = \begin{bmatrix} - \: (x^{(1)})^T \: - \\ -\: (x^{(2)})^T \:- \\ \vdots \\ - \: (x^{(m)})^T \:-  \end{bmatrix} $$
#
# La segunda parte del conjunto de entrenamiento es un vector "y" de 5000 dimensiones que contiene etiquetas para el conjunto de entrenamiento.
#
# Se inicia el ejercicio cargando primero el conjunto de datos.

# %%
# Ingresar imágenes de dígitos de 20x20
# input_layer_size  = 400

# # 10 etiquetas, de 1 a 10 (tomar en cuenta que se asigna "0" a la etiqueta 10)
num_labels = 22

# #  datos de entrenamiento almacenados en los arreglos X, y

# # X, y = data['X'], data['y'].ravel()
# X, y = cleanData[:, 1:], cleanData[:,6]
# # establecer el dígito cero en 0, en lugar del 10 asignado a este conjunto de datos
# # Esto se hace debido a que el conjunto de datos se utilizó en MATLAB donde no hay índice 0
# y[y == 10] = 0

# m = y.size


data = loadData.values
amount_rows = data.shape[0]
train_rows= int(round(amount_rows * 0.8))

# X, y = data[:train_rows, :7], data[:train_rows, 7]

X, y = data[:, :7], data[:, 7]

# X, y = data[:, 1:], data[:train_rows, 0]

print(X)
print(y)
# Out:
# [[ 90.          42.          43.         ...  82.00274423   6.50298529
#   202.9355362 ]
#  [ 85.          58.          41.         ...  80.31964408   7.03809636
#   226.6555374 ]
#  [ 60.          55.          44.         ...  82.3207629    7.84020714
#   263.9642476 ]
#  ...
#  [118.          33.          30.         ...  67.22512329   6.36260785
#   173.3228386 ]
#  [117.          32.          34.         ...  52.12739421   6.75879255
#   127.1752928 ]
#  [104.          18.          30.         ...  60.39647474   6.77983261
#   140.9370415 ]]
# [ 1.  1.  1. ... 22. 22. 22.]

# %% [markdown]
# ### 1.2 Visualización de los datos
#
# Se comenzará visualizando un subconjunto del conjunto de entrenamiento. Se selecciona al azar, 100 filas de `X` y pasa esas filas a la función` displayData`. Esta función asigna cada fila a una imagen en escala de grises de 20 píxeles por 20 píxeles y muestra las imágenes juntas.

# %%
# def displayData(X, example_width=None, figsize=(10, 10)):
#     """
#     Muestra datos 2D almacenados en X en una cuadrícula apropiada.
#     """
#     # Calcula filas, columnas
#     if X.ndim == 2:
#         m, n = X.shape
#     elif X.ndim == 1:
#         n = X.size
#         m = 1
#         X = X[None]  # Promocionar a una matriz bidimensional
#     else:
#         raise IndexError('La entrada X debe ser 1 o 2 dimensinal.')

#     example_width = example_width or int(np.round(np.sqrt(n)))
#     example_height = n / example_width

#     # Calcula el numero de elementos a mostrar
#     display_rows = int(np.floor(np.sqrt(m)))
#     display_cols = int(np.ceil(m / display_rows))

#     fig, ax_array = pyplot.subplots(display_rows, display_cols, figsize=figsize)
#     fig.subplots_adjust(wspace=0.025, hspace=0.025)

#     ax_array = [ax_array] if m == 1 else ax_array.ravel()

#     for i, ax in enumerate(ax_array):
#         ax.imshow(X[i].reshape(example_width, example_width, order='F'),
#                   cmap='Greys', extent=[0, 1, 0, 1])
#         ax.axis('off')

# %%
# # Selecciona aleatoriamente 100 puntos de datos para mostrar
# rand_indices = np.random.choice(m, 100, replace=False)
# sel = X[rand_indices, :]

# displayData(sel)

# %% [markdown]
# ### 1.3 Vectorización de regresión logística
#
# Se utilizará múltiples modelos de regresión logística uno contra todos para construir un clasificador de clases múltiples. Dado que hay 10 clases, deberá entrenar 10 clasificadores de regresión logística separados. Para que esta capacitación sea eficiente, es importante asegurarse de que el código esté bien vectorizado.
#
# En esta sección, se implementará una versión vectorizada de regresión logística que no emplea ningún bucle "for".
#
# Para probar la regresión logística vectorizada, se usara datos personalizados como se definen a continuación.

# %% [markdown]
# <a id="section1"></a>
# #### 1.3.1 Vectorización de la funcion de costo
#
# Se inicia escribiendo una versión vectorizada de la función de costo. En la regresión logística (no regularizada), la función de costo es
#
# $$ J(\theta) = \frac{1}{m} \sum_{i=1}^m \left[ -y^{(i)} \log \left( h_\theta\left( x^{(i)} \right) \right) - \left(1 - y^{(i)} \right) \log \left(1 - h_\theta \left( x^{(i)} \right) \right) \right] $$
#
# Para calcular cada elemento en la suma, tenemos que calcular $h_\theta(x^{(i)})$ para cada ejemplo $i$, donde $h_\theta(x^{(i)}) = g(\theta^T x^{(i)})$ y $g(z) = \frac{1}{1+e^{-z}}$ es la funcion sigmoidea. Resulta que podemos calcular esto rápidamente para todos los ejemplos usando la multiplicación de matrices. Definamos $X$ y $\theta$ como
#
# $$ X = \begin{bmatrix} - \left( x^{(1)} \right)^T - \\ - \left( x^{(2)} \right)^T - \\ \vdots \\ - \left( x^{(m)} \right)^T - \end{bmatrix} \qquad \text{and} \qquad \theta = \begin{bmatrix} \theta_0 \\ \theta_1 \\ \vdots \\ \theta_n \end{bmatrix} $$
#
# Luego, de calcular el producto matricial $X\theta$, se tiene:
#
# $$ X\theta = \begin{bmatrix} - \left( x^{(1)} \right)^T\theta - \\ - \left( x^{(2)} \right)^T\theta - \\ \vdots \\ - \left( x^{(m)} \right)^T\theta - \end{bmatrix} = \begin{bmatrix} - \theta^T x^{(1)}  - \\ - \theta^T x^{(2)} - \\ \vdots \\ - \theta^T x^{(m)}  - \end{bmatrix} $$
#
# En la última igualdad, usamos el hecho de que $a^Tb = b^Ta$ if $a$ y $b$ son vectores. Esto permite calcular los productos $\theta^T x^{(i)}$ para todos los ejemplos $i$ en una linea de codigo.
#
# #### 1.3.2 Vectorización del gradiente
#
# Recordemos que el gradiente del costo de regresión logística (no regularizado) es un vector donde el elemento $j^{th}$ se define como
# $$ \frac{\partial J }{\partial \theta_j} = \frac{1}{m} \sum_{i=1}^m \left( \left( h_\theta\left(x^{(i)}\right) - y^{(i)} \right)x_j^{(i)} \right) $$
#
# Para vectorizar esta operación sobre el conjunto de datos, se inicia escribiendo todas las derivadas parciales explícitamente para todos $\theta_j$,
#
# $$
# \begin{align*}
# \begin{bmatrix}
# \frac{\partial J}{\partial \theta_0} \\
# \frac{\partial J}{\partial \theta_1} \\
# \frac{\partial J}{\partial \theta_2} \\
# \vdots \\
# \frac{\partial J}{\partial \theta_n}
# \end{bmatrix} = &
# \frac{1}{m} \begin{bmatrix}
# \sum_{i=1}^m \left( \left(h_\theta\left(x^{(i)}\right) - y^{(i)} \right)x_0^{(i)}\right) \\
# \sum_{i=1}^m \left( \left(h_\theta\left(x^{(i)}\right) - y^{(i)} \right)x_1^{(i)}\right) \\
# \sum_{i=1}^m \left( \left(h_\theta\left(x^{(i)}\right) - y^{(i)} \right)x_2^{(i)}\right) \\
# \vdots \\
# \sum_{i=1}^m \left( \left(h_\theta\left(x^{(i)}\right) - y^{(i)} \right)x_n^{(i)}\right) \\
# \end{bmatrix} \\
# = & \frac{1}{m} \sum_{i=1}^m \left( \left(h_\theta\left(x^{(i)}\right) - y^{(i)} \right)x^{(i)}\right) \\
# = & \frac{1}{m} X^T \left( h_\theta(x) - y\right)
# \end{align*}
# $$
#
# donde
#
# $$  h_\theta(x) - y =
# \begin{bmatrix}
# h_\theta\left(x^{(1)}\right) - y^{(1)} \\
# h_\theta\left(x^{(2)}\right) - y^{(2)} \\
# \vdots \\
# h_\theta\left(x^{(m)}\right) - y^{(m)}
# \end{bmatrix} $$
#
# Nota $x^{(i)}$ es un vector, mientras $h_\theta\left(x^{(i)}\right) - y^{(i)}$ es un escalar(simple número).
# Para comprender el último paso de la derivación, dejemos $\beta_i = (h_\theta\left(x^{(m)}\right) - y^{(m)})$ y
# observar que:
#
# $$ \sum_i \beta_ix^{(i)} = \begin{bmatrix}
# | & | & & | \\
# x^{(1)} & x^{(2)} & \cdots & x^{(m)} \\
# | & | & & |
# \end{bmatrix}
# \begin{bmatrix}
# \beta_1 \\
# \beta_2 \\
# \vdots \\
# \beta_m
# \end{bmatrix} = x^T \beta
# $$
#
# donde los valores $\beta_i = \left( h_\theta(x^{(i)} - y^{(i)} \right)$.
#
# La expresión anterior nos permite calcular todas las derivadas parciales sin bucles.
# Si se siente cómodo con el álgebra lineal, le recomendamos que trabaje con las multiplicaciones de matrices anteriores para convencerse de que la versión vectorizada hace los mismos cálculos.
#
# <div class="alert alert-box alert-warning">
# ** Consejo de depuración: ** El código de vectorización a veces puede ser complicado. Una estrategia común para la depuración es imprimir los tamaños de las matrices con las que está trabajando usando la propiedad `shape` de las matrices` numpy`.
#
# Por ejemplo, dada una matriz de datos $X$ de tamaño $100\veces 20$ (100 ejemplos, 20 características) y $\theta$, un vector con tamaño $20$, puede observar que `np.dot (X, theta) `es una operación de multiplicación válida, mientras que` np.dot (theta, X) `no lo es.
#
# Además, si tiene una versión no vectorizada de su código, puede comparar la salida de su código vectorizado y el código no vectorizado para asegurarse de que produzcan las mismas salidas.</div>
# <a id="lrCostFunction"></a>

# %%
def sigmoid(z):
    """
    Calcula la sigmoide de z.
    """
    return 1.0 / (1.0 + np.exp(-z))

# %%
def lrCostFunction(theta, X, y, lambda_):
    """
    Calcula el costo de usar theta como parámetro para la regresión logística regularizada y 
    el gradiente del costo w.r.t. a los parámetros.
    
    Parametros
    ----------
    theta : array_like
        Parametro theta de la regresion logistica. Vector de la forma(shape) (n, ). n es el numero de caracteristicas 
        incluida la intercepcion
        
    X : array_like
        Dataset con la forma(shape) (m x n). m es el numero de ejemplos, y n es el numero de 
        caracteristicas (incluida la intercepcion).
    
    y : array_like
        El conjunto de etiquetas. Un vector con la forma (shape) (m, ). m es el numero de ejemplos
    
    lambda_ : float
        Parametro de regularización. 
    
    Devuelve
    -------
    J : float
        El valor calculado para la funcion de costo regularizada. 
    
    grad : array_like
        Un vector de la forma (shape) (n, ) que es el gradiente de la 
        función de costo con respecto a theta, en los valores actuales de theta..
    """
    # Inicializa algunos valores utiles
    m = y.size
    
    # convierte las etiquetas a valores enteros si son boleanos
    if y.dtype == bool:
        y = y.astype(int)
    
    J = 0
    grad = np.zeros(theta.shape)
    
    h = sigmoid(X.dot(theta.T))
    
    temp = theta
    temp[0] = 0
    
    J = (1 / m) * np.sum(-y.dot(np.log(h)) - (1 - y).dot(np.log(1 - h))) + (lambda_ / (2 * m)) * np.sum(np.square(temp))
    
    grad = (1 / m) * (h - y).dot(X) 
    grad = grad + (lambda_ / m) * temp

    return J, grad

# %%
def  featureNormalize(X):
    X_norm = X.copy()
    mu = np.zeros(X.shape[1])
    sigma = np.zeros(X.shape[1])

    mu = np.mean(X, axis = 0)
    sigma = np.std(X, axis = 0)
    X_norm = (X - mu) / sigma
    
    return X_norm, mu, sigma

# %% [markdown]
# #### 1.3.3 Vectorización regularizada de la regresión logística
#
# Una vez implementada la vectorización para la regresión logística, corresponde agregarar regularización a la función de costo.
# Para la regresión logística regularizada, la función de costo se define como
#
# $$ J(\theta) = \frac{1}{m} \sum_{i=1}^m \left[ -y^{(i)} \log \left(h_\theta\left(x^{(i)} \right)\right) - \left( 1 - y^{(i)} \right) \log\left(1 - h_\theta \left(x^{(i)} \right) \right) \right] + \frac{\lambda}{2m} \sum_{j=1}^n \theta_j^2 $$
#
# Tomar en cuenta que no debería regularizarse $\theta_0$ que se usa para el término de sesgo. En consecuencia, la derivada parcial del costo de regresión logística regularizado para $\theta_j$ se define como
#
# $$
# \begin{align*}
# & \frac{\partial J(\theta)}{\partial \theta_0} = \frac{1}{m} \sum_{i=1}^m \left( h_\theta\left( x^{(i)} \right) - y^{(i)} \right) x_j^{(i)}  & \text{for } j = 0 \\
# & \frac{\partial J(\theta)}{\partial \theta_0} = \left( \frac{1}{m} \sum_{i=1}^m \left( h_\theta\left( x^{(i)} \right) - y^{(i)} \right) x_j^{(i)} \right) + \frac{\lambda}{m} \theta_j & \text{for } j  \ge 1
# \end{align*}
# $$
#
# <div class="alert alert-box alert-warning">
# ** Python/numpy Consejo: ** Al implementar la vectorización para la regresión logística regularizada, a menudo es posible que solo desee sumar y actualizar ciertos elementos de $\theta$. En `numpy`, puede indexar en las matrices para acceder y actualizar solo ciertos elementos.
#
# Por ejemplo, A [:, 3: 5] = B [:, 1: 3] reemplazará las columnas con índice 3 a 5 de A con las columnas con índice 1 a 3 de B.
# Para seleccionar columnas (o filas) hasta el final de la matriz, puede dejar el lado derecho de los dos puntos en blanco.
# Por ejemplo, A [:, 2:] solo devolverá elementos desde $3^{rd}$ a las últimas columnas de $A$.Si deja el tamaño de la mano izquierda de los dos puntos en blanco, seleccionará los elementos del principio de la matriz.
# Por ejemplo, A [:,: 2] selecciona las dos primeras columnas y es equivalente a A [:, 0: 2]. Además, puede utilizar índices negativos para indexar matrices desde el final.
# Por lo tanto, A [:,: -1] selecciona todas las columnas de A excepto la última columna, y A [:, -5:] selecciona la columna $5^{th}$ desde el final hasta la última columna.
#
# Por lo tanto, podría usar esto junto con las operaciones de suma y potencia ($^{**}$) para calcular la suma de solo los elementos que le interesan (por ejemplo, `np.sum (z[1:]**2)`).
# </div>

# %%
# J, grad = lrCostFunction(theta_t, X_t, y_t, lambda_t)

# print('Costo         : {:.6f}'.format(J))
# print('Costo esperadot: 2.534819')
# print('-----------------------')
# print('Gradientes:')
# print(' [{:.6f}, {:.6f}, {:.6f}, {:.6f}]'.format(*grad))
# print('Gradientes esperados:')
# print(' [0.146561, -0.548558, 0.724722, 1.398003]');

# %% [markdown]
# <a id="section2"></a>
# ### 1.4 Clasificacion One-vs-all
# En esta parte del ejercicio, se implementará la clasificación de uno contra todos mediante el entrenamiento de múltiples clasificadores de regresión logística regularizados, uno para cada una de las clases $K$ en nuestro conjunto de datos. En el conjunto de datos de dígitos escritos a mano, $K = 10$, pero su código debería funcionar para cualquier valor de $K$.
#
# El argumento `y` de esta función es un vector de etiquetas de 0 a 9. Al entrenar el clasificador para la clase $k \in \{0, ..., K-1 \} $, querrá un vector K-dimensional de etiquetas $y$, donde $y_j \ in 0, 1$ indica si la instancia de entrenamiento $j ^ {th}$ pertenece a la clase $k$ $(y_j = 1)$, o si pertenece a una clase diferente $(y_j = 0)$.
#
# Además, se utiliza `optimize.minimize` de scipy para este ejercicio.
# <a id="oneVsAll"></a>

# %%
def oneVsAll(X, y, num_labels, lambda_):
    """
    Trains num_labels logistic regression classifiers and returns
    each of these classifiers in a matrix all_theta, where the i-th
    row of all_theta corresponds to the classifier for label i.
    
    Parameters
    ----------
    X : array_like
        The input dataset of shape (m x n). m is the number of 
        data points, and n is the number of features. Note that we 
        do not assume that the intercept term (or bias) is in X, however
        we provide the code below to add the bias term to X. 
    
    y : array_like
        The data labels. A vector of shape (m, ).
    
    num_labels : int
        Number of possible labels.
    
    lambda_ : float
        The logistic regularization parameter.
    
    Returns
    -------
    all_theta : array_like
        The trained parameters for logistic regression for each class.
        This is a matrix of shape (K x n+1) where K is number of classes
        (ie. `numlabels`) and n is number of features without the bias.
    """
    # algunas variables utiles
    m, n = X.shape
    
    all_theta = np.zeros((num_labels, n + 1))

    # Agrega unos a la matriz X
    X = np.concatenate([np.ones((m, 1)), X], axis=1)

    for c in np.arange(num_labels):
        initial_theta = np.zeros(n + 1)
        options = {'maxiter': 50}
        res = optimize.minimize(lrCostFunction, 
                                initial_theta, 
                                (X, (y == c), lambda_), 
                                jac=True, 
                                method='BFGS',
                                options=options) 
        
        all_theta[c] = res.x

    return all_theta

# %%
X_norm, mu, sigma = featureNormalize(X)

# %%
lambda_ = 0.1
all_theta = oneVsAll(X, y, num_labels, lambda_)
# all_theta = oneVsAll(X_norm, y, num_labels, lambda_)
print(all_theta)
# Out:
# C:\Users\Carlos Osmar\AppData\Local\Temp\ipykernel_24156\1892987983.py:46: RuntimeWarning: divide by zero encountered in log
#   J = (1 / m) * np.sum(-y.dot(np.log(h)) - (1 - y).dot(np.log(1 - h))) + (lambda_ / (2 * m)) * np.sum(np.square(temp))
# C:\Users\Carlos Osmar\AppData\Local\Temp\ipykernel_24156\1892987983.py:46: RuntimeWarning: divide by zero encountered in log
#   J = (1 / m) * np.sum(-y.dot(np.log(h)) - (1 - y).dot(np.log(1 - h))) + (lambda_ / (2 * m)) * np.sum(np.square(temp))
# C:\Users\Carlos Osmar\AppData\Local\Temp\ipykernel_24156\1892987983.py:46: RuntimeWarning: divide by zero encountered in log
#   J = (1 / m) * np.sum(-y.dot(np.log(h)) - (1 - y).dot(np.log(1 - h))) + (lambda_ / (2 * m)) * np.sum(np.square(temp))
# C:\Users\Carlos Osmar\AppData\Local\Temp\ipykernel_24156\1892987983.py:46: RuntimeWarning: divide by zero encountered in log
#   J = (1 / m) * np.sum(-y.dot(np.log(h)) - (1 - y).dot(np.log(1 - h))) + (lambda_ / (2 * m)) * np.sum(np.square(temp))
# C:\Users\Carlos Osmar\AppData\Local\Temp\ipykernel_24156\1892987983.py:46: RuntimeWarning: divide by zero encountered in log
#   J = (1 / m) * np.sum(-y.dot(np.log(h)) - (1 - y).dot(np.log(1 - h))) + (lambda_ / (2 * m)) * np.sum(np.square(temp))
#   -1.16499237e-01  1.34746768e-01 -8.64283453e+00  1.41012896e-01]
#  [ 6.26533582e-02 -5.82529160e-02 -2.55877043e-01 -1.01488968e+00
#   -1.19390286e+00  5.00024470e-01  2.38189567e+00 -1.21733334e-02]
#  [-1.20272329e+02  4.65829967e-02  1.70075943e-01 -8.53644035e-02
#    3.98004482e-01  8.70925382e-01  2.86031239e+00  1.45788901e-02]
#  [-9.58569557e-01 -1.06519767e-01 -2.54728264e-01 -4.10214876e-02
#    2.73628643e-01  3.44199966e-01 -6.88258087e+00  8.57373408e-02]
#  [-3.40530446e+01  3.14829707e-01 -2.90029525e-02 -5.66374569e-01
#   -2.27303142e-01  4.39765937e-01 -1.91386995e+00 -3.38020235e-03]
#  [-1.27202112e+01  2.14978985e-02  5.06631443e-03 -1.94897239e-03
#   -4.90479054e-02  2.67553512e-02  7.47458742e-01  1.76790852e-02]]
# C:\Users\Carlos Osmar\AppData\Local\Temp\ipykernel_24156\1892987983.py:46: RuntimeWarning: divide by zero encountered in log
#   J = (1 / m) * np.sum(-y.dot(np.log(h)) - (1 - y).dot(np.log(1 - h))) + (lambda_ / (2 * m)) * np.sum(np.square(temp))
# C:\Users\Carlos Osmar\AppData\Local\Temp\ipykernel_24156\1892987983.py:46: RuntimeWarning: divide by zero encountered in log
#   J = (1 / m) * np.sum(-y.dot(np.log(h)) - (1 - y).dot(np.log(1 - h))) + (lambda_ / (2 * m)) * np.sum(np.square(temp))
# C:\Users\Carlos Osmar\AppData\Local\Temp\ipykernel_24156\1892987983.py:46: RuntimeWarning: divide by zero encountered in log
#   J = (1 / m) * np.sum(-y.dot(np.log(h)) - (1 - y).dot(np.log(1 - h))) + (lambda_ / (2 * m)) * np.sum(np.square(temp))

# %% [markdown]
# <a id="section3"></a>
# #### 1.4.1 Prediccion One-vs-all
#
# Después de entrenar el clasificador de one-vs-all, se puede usarlo para predecir el dígito contenido en una imagen determinada. Para cada entrada, debe calcular la "probabilidad" de que pertenezca a cada clase utilizando los clasificadores de regresión logística entrenados. La función de predicción one-vs-all seleccionará la clase para la cual el clasificador de regresión logística correspondiente genera la probabilidad más alta y devolverá la etiqueta de clase (0, 1, ..., K-1) como la predicción para el ejemplo de entrada.

# %%
def predictOneVsAll(all_theta, X):
    """
    Devuelve un vector de predicciones para cada ejemplo en la matriz X.
    Tenga en cuenta que X contiene los ejemplos en filas. 
    all_theta es una matriz donde la i-ésima fila es un vector theta de regresión logística entrenada para la i-ésima clase. 
    Debe establecer p en un vector de valores de 0..K-1 (por ejemplo, p = [0, 2, 0, 1] 
    predice clases 0, 2, 0, 1 para 4 ejemplos).
    
    Parametros
    ----------
    all_theta : array_like
        The trained parameters for logistic regression for each class.
        This is a matrix of shape (K x n+1) where K is number of classes
        and n is number of features without the bias.
    
    X : array_like
        Data points to predict their labels. This is a matrix of shape 
        (m x n) where m is number of data points to predict, and n is number 
        of features without the bias term. Note we add the bias term for X in 
        this function. 
    
    Devuelve
    -------
    p : array_like
        The predictions for each data point in X. This is a vector of shape (m, ).
    """
    
    m = X.shape[0]
    num_labels = all_theta.shape[0]

    p = np.zeros(m)

    # Add ones to the X data matrix
    X = np.concatenate([np.ones((m, 1)), X], axis=1)
    p = np.argmax(sigmoid(X.dot(all_theta.T)), axis = 1)

    return p

# %% [markdown]
# Una vez que haya terminado, se llama a la función `predictOneVsAll` usando el valor aprendido de $\theta$. Debería apreciarse que la precisión del conjunto de entrenamiento es de aproximadamente 95,1% (es decir, clasifica correctamente el 95,1% de los ejemplos del conjunto de entrenamiento).

# %%
print(X.shape)
# print(all_theta)
pred = predictOneVsAll(all_theta, X)
# pred = predictOneVsAll(all_theta, X)
print('Precision del conjuto de entrenamiento: {:.2f}%'.format(np.mean(pred == y) * 100))



# m,n = X_norm.shape
# data = loadData.values
# amount_rows = data.shape[0]
# test_rows= int(round(amount_rows * 0.2))
# X, y = data[test_rows:, :7], data[test_rows:, 7]
# XPrueba = X[:,:].copy()
# XLast = np.concatenate((np.ones((m, 1)), XPrueba), axis=1)


data = loadData.values
amount_rows = data.shape[0]
test_rows= int(round(amount_rows * 0.2))
X, y = data[test_rows:, :7], data[test_rows:, 7]
m,n = X.shape
XPrueba = X[:,:].copy()
XLast = np.concatenate((np.ones((m, 1)), XPrueba), axis=1)

# yPrueba = y[2143:2148].copy()
# XPrueba = X[2147:2148,:].copy()
# XPrueba = np.concatenate((np.ones((1, 1)), XPrueba), axis=1)

# p = np.zeros(7)

p = np.argmax(sigmoid(XLast.dot(all_theta.T)), axis = 1)
print(p)




# print(XPrueba.shape)
# print(XPrueba)








# # XPrueba = X[4002:4003, :].copy()
# # print(XPrueba.shape)
# # #print(np.ones((1)))
# # #print(XPrueba)
# X_norm, mu, sigma = featureNormalize(X)
# p = np.zeros(7)
# X = np.concatenate([np.ones((m, 1)), X], axis=1)
# p = np.argmax(sigmoid(X.dot(all_theta.T)), axis = 1)
# # print(XPrueba.shape)
# '''TEST TERCER METODO '''



# test = sigmoid(np.dot(p,all_theta))
# # binario = [1 if elemento > 0.5 else 0 for elemento in test]

# # binario = np.where(test >= 0.5, 1, 0)

# # test = sigmoid(X_FINAL.dot(theta.T))
# print('Precisión de entrenamiento: {:.2f} %'.format(np.mean(test == y) * 100))

# displayData(X[4002:4003, :])
# Out:
# (2200, 7)
# Precision del conjuto de entrenamiento: 92.14%
# [ 5  5  5 ...  1 21 14]

# %%
# # impresion de los datos predecidos y los reales
for i in range(m):
    print("Ejemplo", i+1, "- Predicción:", p[i], "- Valor real:", y[i])
# Out:
# Ejemplo 1 - Predicción: 5 - Valor real: 5.0
# Ejemplo 2 - Predicción: 5 - Valor real: 5.0
# Ejemplo 3 - Predicción: 5 - Valor real: 5.0
# Ejemplo 4 - Predicción: 5 - Valor real: 5.0
# Ejemplo 5 - Predicción: 5 - Valor real: 5.0
# Ejemplo 6 - Predicción: 8 - Valor real: 5.0
# Ejemplo 7 - Predicción: 5 - Valor real: 5.0
# Ejemplo 8 - Predicción: 5 - Valor real: 5.0
# Ejemplo 9 - Predicción: 5 - Valor real: 5.0
# Ejemplo 10 - Predicción: 5 - Valor real: 5.0
# Ejemplo 11 - Predicción: 5 - Valor real: 5.0
# Ejemplo 12 - Predicción: 5 - Valor real: 5.0
# Ejemplo 13 - Predicción: 5 - Valor real: 5.0
# Ejemplo 14 - Predicción: 5 - Valor real: 5.0
# Ejemplo 15 - Predicción: 5 - Valor real: 5.0
# Ejemplo 16 - Predicción: 5 - Valor real: 5.0
# Ejemplo 17 - Predicción: 5 - Valor real: 5.0
# Ejemplo 18 - Predicción: 5 - Valor real: 5.0
# Ejemplo 19 - Predicción: 5 - Valor real: 5.0
# Ejemplo 20 - Predicción: 5 - Valor real: 5.0
# Ejemplo 21 - Predicción: 5 - Valor real: 5.0
# Ejemplo 22 - Predicción: 5 - Valor real: 5.0
# Ejemplo 23 - Predicción: 5 - Valor real: 5.0
# Ejemplo 24 - Predicción: 5 - Valor real: 5.0
# Ejemplo 25 - Predicción: 8 - Valor real: 5.0
# Ejemplo 26 - Predicción: 5 - Valor real: 5.0
# Ejemplo 27 - Predicción: 5 - Valor real: 5.0
# Ejemplo 28 - Predicción: 5 - Valor real: 5.0
# Ejemplo 29 - Predicción: 5 - Valor real: 5.0
# Ejemplo 30 - Predicción: 21 - Valor real: 5.0
# Ejemplo 31 - Predicción: 5 - Valor real: 5.0
# Ejemplo 32 - Predicción: 5 - Valor real: 5.0
# Ejemplo 33 - Predicción: 5 - Valor real: 5.0
# Ejemplo 34 - Predicción: 5 - Valor real: 5.0
# Ejemplo 35 - Predicción: 5 - Valor real: 5.0
# Ejemplo 36 - Predicción: 5 - Valor real: 5.0
# Ejemplo 37 - Predicción: 5 - Valor real: 5.0
# Ejemplo 38 - Predicción: 5 - Valor real: 5.0
# Ejemplo 39 - Predicción: 5 - Valor real: 5.0
# Ejemplo 40 - Predicción: 5 - Valor real: 5.0
# Ejemplo 41 - Predicción: 5 - Valor real: 5.0
# Ejemplo 42 - Predicción: 5 - Valor real: 5.0
# Ejemplo 43 - Predicción: 5 - Valor real: 5.0
# Ejemplo 44 - Predicción: 5 - Valor real: 5.0
# Ejemplo 45 - Predicción: 5 - Valor real: 5.0
# Ejemplo 46 - Predicción: 21 - Valor real: 5.0
# Ejemplo 47 - Predicción: 5 - Valor real: 5.0
# Ejemplo 48 - Predicción: 5 - Valor real: 5.0
# Ejemplo 49 - Predicción: 5 - Valor real: 5.0
# Ejemplo 50 - Predicción: 5 - Valor real: 5.0
# Ejemplo 51 - Predicción: 5 - Valor real: 5.0
# Ejemplo 52 - Predicción: 5 - Valor real: 5.0
# Ejemplo 53 - Predicción: 5 - Valor real: 5.0
# Ejemplo 54 - Predicción: 5 - Valor real: 5.0
# Ejemplo 55 - Predicción: 5 - Valor real: 5.0
# Ejemplo 56 - Predicción: 5 - Valor real: 5.0
# Ejemplo 57 - Predicción: 5 - Valor real: 5.0
# Ejemplo 58 - Predicción: 5 - Valor real: 5.0
# Ejemplo 59 - Predicción: 5 - Valor real: 5.0
# Ejemplo 60 - Predicción: 2 - Valor real: 5.0
# Ejemplo 61 - Predicción: 7 - Valor real: 6.0
# Ejemplo 62 - Predicción: 6 - Valor real: 6.0
# Ejemplo 63 - Predicción: 6 - Valor real: 6.0
# Ejemplo 64 - Predicción: 6 - Valor real: 6.0
# Ejemplo 65 - Predicción: 6 - Valor real: 6.0
# Ejemplo 66 - Predicción: 6 - Valor real: 6.0
# Ejemplo 67 - Predicción: 6 - Valor real: 6.0
# Ejemplo 68 - Predicción: 6 - Valor real: 6.0
# Ejemplo 69 - Predicción: 6 - Valor real: 6.0
# Ejemplo 70 - Predicción: 6 - Valor real: 6.0
# Ejemplo 71 - Predicción: 6 - Valor real: 6.0
# Ejemplo 72 - Predicción: 6 - Valor real: 6.0
# Ejemplo 73 - Predicción: 6 - Valor real: 6.0
# Ejemplo 74 - Predicción: 6 - Valor real: 6.0
# Ejemplo 75 - Predicción: 6 - Valor real: 6.0
# Ejemplo 76 - Predicción: 6 - Valor real: 6.0
# Ejemplo 77 - Predicción: 6 - Valor real: 6.0
# Ejemplo 78 - Predicción: 6 - Valor real: 6.0
# Ejemplo 79 - Predicción: 6 - Valor real: 6.0
# Ejemplo 80 - Predicción: 6 - Valor real: 6.0
# Ejemplo 81 - Predicción: 6 - Valor real: 6.0
# Ejemplo 82 - Predicción: 2 - Valor real: 6.0
# Ejemplo 83 - Predicción: 6 - Valor real: 6.0
# Ejemplo 84 - Predicción: 6 - Valor real: 6.0
# Ejemplo 85 - Predicción: 6 - Valor real: 6.0
# Ejemplo 86 - Predicción: 6 - Valor real: 6.0
# Ejemplo 87 - Predicción: 6 - Valor real: 6.0
# Ejemplo 88 - Predicción: 6 - Valor real: 6.0
# Ejemplo 89 - Predicción: 6 - Valor real: 6.0
# Ejemplo 90 - Predicción: 6 - Valor real: 6.0
# Ejemplo 91 - Predicción: 6 - Valor real: 6.0
# Ejemplo 92 - Predicción: 6 - Valor real: 6.0
# Ejemplo 93 - Predicción: 6 - Valor real: 6.0
# Ejemplo 94 - Predicción: 6 - Valor real: 6.0
# Ejemplo 95 - Predicción: 6 - Valor real: 6.0
# Ejemplo 96 - Predicción: 6 - Valor real: 6.0
# Ejemplo 97 - Predicción: 6 - Valor real: 6.0
# Ejemplo 98 - Predicción: 5 - Valor real: 6.0
# Ejemplo 99 - Predicción: 2 - Valor real: 6.0
# Ejemplo 100 - Predicción: 6 - Valor real: 6.0
# Ejemplo 101 - Predicción: 6 - Valor real: 6.0
# Ejemplo 102 - Predicción: 6 - Valor real: 6.0
# Ejemplo 103 - Predicción: 6 - Valor real: 6.0
# Ejemplo 104 - Predicción: 6 - Valor real: 6.0
# Ejemplo 105 - Predicción: 6 - Valor real: 6.0
# Ejemplo 106 - Predicción: 6 - Valor real: 6.0
# Ejemplo 107 - Predicción: 6 - Valor real: 6.0
# Ejemplo 108 - Predicción: 6 - Valor real: 6.0
# Ejemplo 109 - Predicción: 6 - Valor real: 6.0
# Ejemplo 110 - Predicción: 6 - Valor real: 6.0
# Ejemplo 111 - Predicción: 6 - Valor real: 6.0
# Ejemplo 112 - Predicción: 6 - Valor real: 6.0
# Ejemplo 113 - Predicción: 6 - Valor real: 6.0
# Ejemplo 114 - Predicción: 6 - Valor real: 6.0
# Ejemplo 115 - Predicción: 6 - Valor real: 6.0
# Ejemplo 116 - Predicción: 6 - Valor real: 6.0
# Ejemplo 117 - Predicción: 6 - Valor real: 6.0
# Ejemplo 118 - Predicción: 5 - Valor real: 6.0
# Ejemplo 119 - Predicción: 6 - Valor real: 6.0
# Ejemplo 120 - Predicción: 6 - Valor real: 6.0
# Ejemplo 121 - Predicción: 6 - Valor real: 6.0
# Ejemplo 274 - Predicción: 8 - Valor real: 8.0
# Ejemplo 275 - Predicción: 8 - Valor real: 8.0
# Ejemplo 276 - Predicción: 8 - Valor real: 8.0
# Ejemplo 277 - Predicción: 8 - Valor real: 8.0
# Ejemplo 278 - Predicción: 8 - Valor real: 8.0
# Ejemplo 279 - Predicción: 8 - Valor real: 8.0
# Ejemplo 280 - Predicción: 8 - Valor real: 8.0
# Ejemplo 281 - Predicción: 8 - Valor real: 8.0
# Ejemplo 282 - Predicción: 8 - Valor real: 8.0
# Ejemplo 283 - Predicción: 8 - Valor real: 8.0
# Ejemplo 284 - Predicción: 8 - Valor real: 8.0
# Ejemplo 285 - Predicción: 8 - Valor real: 8.0
# Ejemplo 286 - Predicción: 8 - Valor real: 8.0
# Ejemplo 287 - Predicción: 8 - Valor real: 8.0
# Ejemplo 288 - Predicción: 8 - Valor real: 8.0
# Ejemplo 289 - Predicción: 8 - Valor real: 8.0
# Ejemplo 290 - Predicción: 8 - Valor real: 8.0
# Ejemplo 291 - Predicción: 8 - Valor real: 8.0
# Ejemplo 292 - Predicción: 8 - Valor real: 8.0
# Ejemplo 293 - Predicción: 8 - Valor real: 8.0
# Ejemplo 294 - Predicción: 8 - Valor real: 8.0
# Ejemplo 295 - Predicción: 8 - Valor real: 8.0
# Ejemplo 296 - Predicción: 8 - Valor real: 8.0
# Ejemplo 297 - Predicción: 8 - Valor real: 8.0
# Ejemplo 298 - Predicción: 8 - Valor real: 8.0
# Ejemplo 299 - Predicción: 8 - Valor real: 8.0
# Ejemplo 300 - Predicción: 8 - Valor real: 8.0
# Ejemplo 301 - Predicción: 8 - Valor real: 8.0
# Ejemplo 302 - Predicción: 8 - Valor real: 8.0
# Ejemplo 303 - Predicción: 8 - Valor real: 8.0
# Ejemplo 304 - Predicción: 8 - Valor real: 8.0
# Ejemplo 305 - Predicción: 8 - Valor real: 8.0
# Ejemplo 306 - Predicción: 8 - Valor real: 8.0
# Ejemplo 307 - Predicción: 9 - Valor real: 8.0
# Ejemplo 308 - Predicción: 8 - Valor real: 8.0
# Ejemplo 309 - Predicción: 8 - Valor real: 8.0
# Ejemplo 310 - Predicción: 8 - Valor real: 8.0
# Ejemplo 311 - Predicción: 8 - Valor real: 8.0
# Ejemplo 312 - Predicción: 8 - Valor real: 8.0
# Ejemplo 313 - Predicción: 8 - Valor real: 8.0
# Ejemplo 314 - Predicción: 8 - Valor real: 8.0
# Ejemplo 315 - Predicción: 8 - Valor real: 8.0
# Ejemplo 316 - Predicción: 8 - Valor real: 8.0
# Ejemplo 317 - Predicción: 8 - Valor real: 8.0
# Ejemplo 318 - Predicción: 8 - Valor real: 8.0
# Ejemplo 319 - Predicción: 8 - Valor real: 8.0
# Ejemplo 320 - Predicción: 8 - Valor real: 8.0
# Ejemplo 321 - Predicción: 8 - Valor real: 8.0
# Ejemplo 322 - Predicción: 8 - Valor real: 8.0
# Ejemplo 323 - Predicción: 8 - Valor real: 8.0
# Ejemplo 324 - Predicción: 8 - Valor real: 8.0
# Ejemplo 325 - Predicción: 8 - Valor real: 8.0
# Ejemplo 326 - Predicción: 8 - Valor real: 8.0
# Ejemplo 327 - Predicción: 8 - Valor real: 8.0
# Ejemplo 328 - Predicción: 8 - Valor real: 8.0
# Ejemplo 329 - Predicción: 8 - Valor real: 8.0
# Ejemplo 330 - Predicción: 8 - Valor real: 8.0
# Ejemplo 331 - Predicción: 8 - Valor real: 8.0
# Ejemplo 332 - Predicción: 8 - Valor real: 8.0
# Ejemplo 333 - Predicción: 8 - Valor real: 8.0
# Ejemplo 334 - Predicción: 8 - Valor real: 8.0
# Ejemplo 335 - Predicción: 8 - Valor real: 8.0
# Ejemplo 336 - Predicción: 8 - Valor real: 8.0
# Ejemplo 337 - Predicción: 8 - Valor real: 8.0
# Ejemplo 338 - Predicción: 8 - Valor real: 8.0
# Ejemplo 339 - Predicción: 8 - Valor real: 8.0
# Ejemplo 340 - Predicción: 8 - Valor real: 8.0
# Ejemplo 341 - Predicción: 8 - Valor real: 8.0
# Ejemplo 342 - Predicción: 8 - Valor real: 8.0
# Ejemplo 343 - Predicción: 8 - Valor real: 8.0
# Ejemplo 344 - Predicción: 8 - Valor real: 8.0
# Ejemplo 345 - Predicción: 8 - Valor real: 8.0
# Ejemplo 346 - Predicción: 8 - Valor real: 8.0
# Ejemplo 347 - Predicción: 8 - Valor real: 8.0
# Ejemplo 348 - Predicción: 8 - Valor real: 8.0
# Ejemplo 349 - Predicción: 8 - Valor real: 8.0
# Ejemplo 350 - Predicción: 8 - Valor real: 8.0
# Ejemplo 351 - Predicción: 8 - Valor real: 8.0
# Ejemplo 352 - Predicción: 8 - Valor real: 8.0
# Ejemplo 353 - Predicción: 8 - Valor real: 8.0
# Ejemplo 354 - Predicción: 8 - Valor real: 8.0
# Ejemplo 355 - Predicción: 8 - Valor real: 8.0
# Ejemplo 356 - Predicción: 8 - Valor real: 8.0
# Ejemplo 357 - Predicción: 8 - Valor real: 8.0
# Ejemplo 358 - Predicción: 8 - Valor real: 8.0
# Ejemplo 359 - Predicción: 8 - Valor real: 8.0
# Ejemplo 360 - Predicción: 8 - Valor real: 8.0
# Ejemplo 361 - Predicción: 9 - Valor real: 9.0
# Ejemplo 362 - Predicción: 9 - Valor real: 9.0
# Ejemplo 363 - Predicción: 6 - Valor real: 9.0
# Ejemplo 364 - Predicción: 9 - Valor real: 9.0
# Ejemplo 365 - Predicción: 9 - Valor real: 9.0
# Ejemplo 366 - Predicción: 9 - Valor real: 9.0
# Ejemplo 367 - Predicción: 9 - Valor real: 9.0
# Ejemplo 368 - Predicción: 9 - Valor real: 9.0
# Ejemplo 369 - Predicción: 9 - Valor real: 9.0
# Ejemplo 370 - Predicción: 9 - Valor real: 9.0
# Ejemplo 371 - Predicción: 9 - Valor real: 9.0
# Ejemplo 372 - Predicción: 9 - Valor real: 9.0
# Ejemplo 373 - Predicción: 9 - Valor real: 9.0
# Ejemplo 374 - Predicción: 9 - Valor real: 9.0
# Ejemplo 426 - Predicción: 9 - Valor real: 9.0
# Ejemplo 427 - Predicción: 9 - Valor real: 9.0
# Ejemplo 428 - Predicción: 9 - Valor real: 9.0
# Ejemplo 429 - Predicción: 9 - Valor real: 9.0
# Ejemplo 430 - Predicción: 9 - Valor real: 9.0
# Ejemplo 431 - Predicción: 9 - Valor real: 9.0
# Ejemplo 432 - Predicción: 9 - Valor real: 9.0
# Ejemplo 433 - Predicción: 9 - Valor real: 9.0
# Ejemplo 434 - Predicción: 9 - Valor real: 9.0
# Ejemplo 435 - Predicción: 9 - Valor real: 9.0
# Ejemplo 436 - Predicción: 9 - Valor real: 9.0
# Ejemplo 437 - Predicción: 9 - Valor real: 9.0
# Ejemplo 438 - Predicción: 8 - Valor real: 9.0
# Ejemplo 439 - Predicción: 9 - Valor real: 9.0
# Ejemplo 440 - Predicción: 9 - Valor real: 9.0
# Ejemplo 441 - Predicción: 9 - Valor real: 9.0
# Ejemplo 442 - Predicción: 9 - Valor real: 9.0
# Ejemplo 443 - Predicción: 9 - Valor real: 9.0
# Ejemplo 444 - Predicción: 9 - Valor real: 9.0
# Ejemplo 445 - Predicción: 9 - Valor real: 9.0
# Ejemplo 446 - Predicción: 9 - Valor real: 9.0
# Ejemplo 447 - Predicción: 9 - Valor real: 9.0
# Ejemplo 448 - Predicción: 9 - Valor real: 9.0
# Ejemplo 449 - Predicción: 9 - Valor real: 9.0
# Ejemplo 450 - Predicción: 9 - Valor real: 9.0
# Ejemplo 451 - Predicción: 9 - Valor real: 9.0
# Ejemplo 452 - Predicción: 9 - Valor real: 9.0
# Ejemplo 453 - Predicción: 9 - Valor real: 9.0
# Ejemplo 454 - Predicción: 6 - Valor real: 9.0
# Ejemplo 455 - Predicción: 9 - Valor real: 9.0
# Ejemplo 456 - Predicción: 9 - Valor real: 9.0
# Ejemplo 457 - Predicción: 9 - Valor real: 9.0
# Ejemplo 458 - Predicción: 9 - Valor real: 9.0
# Ejemplo 459 - Predicción: 9 - Valor real: 9.0
# Ejemplo 460 - Predicción: 9 - Valor real: 9.0
# Ejemplo 461 - Predicción: 10 - Valor real: 10.0
# Ejemplo 462 - Predicción: 10 - Valor real: 10.0
# Ejemplo 463 - Predicción: 10 - Valor real: 10.0
# Ejemplo 464 - Predicción: 10 - Valor real: 10.0
# Ejemplo 465 - Predicción: 10 - Valor real: 10.0
# Ejemplo 466 - Predicción: 10 - Valor real: 10.0
# Ejemplo 467 - Predicción: 10 - Valor real: 10.0
# Ejemplo 468 - Predicción: 10 - Valor real: 10.0
# Ejemplo 469 - Predicción: 10 - Valor real: 10.0
# Ejemplo 470 - Predicción: 10 - Valor real: 10.0
# Ejemplo 471 - Predicción: 10 - Valor real: 10.0
# Ejemplo 472 - Predicción: 10 - Valor real: 10.0
# Ejemplo 473 - Predicción: 10 - Valor real: 10.0
# Ejemplo 474 - Predicción: 10 - Valor real: 10.0
# Ejemplo 475 - Predicción: 10 - Valor real: 10.0
# Ejemplo 476 - Predicción: 10 - Valor real: 10.0
# Ejemplo 477 - Predicción: 10 - Valor real: 10.0
# Ejemplo 478 - Predicción: 10 - Valor real: 10.0
# Ejemplo 479 - Predicción: 10 - Valor real: 10.0
# Ejemplo 480 - Predicción: 10 - Valor real: 10.0
# Ejemplo 481 - Predicción: 10 - Valor real: 10.0
# Ejemplo 482 - Predicción: 10 - Valor real: 10.0
# Ejemplo 483 - Predicción: 10 - Valor real: 10.0
# Ejemplo 484 - Predicción: 10 - Valor real: 10.0
# Ejemplo 485 - Predicción: 10 - Valor real: 10.0
# Ejemplo 486 - Predicción: 10 - Valor real: 10.0
# Ejemplo 487 - Predicción: 10 - Valor real: 10.0
# Ejemplo 488 - Predicción: 10 - Valor real: 10.0
# Ejemplo 489 - Predicción: 10 - Valor real: 10.0
# Ejemplo 490 - Predicción: 10 - Valor real: 10.0
# Ejemplo 491 - Predicción: 10 - Valor real: 10.0
# Ejemplo 492 - Predicción: 10 - Valor real: 10.0
# Ejemplo 493 - Predicción: 10 - Valor real: 10.0
# Ejemplo 494 - Predicción: 10 - Valor real: 10.0
# Ejemplo 495 - Predicción: 10 - Valor real: 10.0
# Ejemplo 496 - Predicción: 10 - Valor real: 10.0
# Ejemplo 497 - Predicción: 10 - Valor real: 10.0
# Ejemplo 498 - Predicción: 10 - Valor real: 10.0
# Ejemplo 499 - Predicción: 10 - Valor real: 10.0
# Ejemplo 500 - Predicción: 10 - Valor real: 10.0
# Ejemplo 501 - Predicción: 21 - Valor real: 10.0
# Ejemplo 502 - Predicción: 10 - Valor real: 10.0
# Ejemplo 503 - Predicción: 10 - Valor real: 10.0
# Ejemplo 504 - Predicción: 10 - Valor real: 10.0
# Ejemplo 505 - Predicción: 10 - Valor real: 10.0
# Ejemplo 506 - Predicción: 10 - Valor real: 10.0
# Ejemplo 507 - Predicción: 10 - Valor real: 10.0
# Ejemplo 508 - Predicción: 10 - Valor real: 10.0
# Ejemplo 509 - Predicción: 10 - Valor real: 10.0
# Ejemplo 510 - Predicción: 10 - Valor real: 10.0
# Ejemplo 511 - Predicción: 10 - Valor real: 10.0
# Ejemplo 512 - Predicción: 10 - Valor real: 10.0
# Ejemplo 513 - Predicción: 10 - Valor real: 10.0
# Ejemplo 514 - Predicción: 10 - Valor real: 10.0
# Ejemplo 515 - Predicción: 10 - Valor real: 10.0
# Ejemplo 516 - Predicción: 10 - Valor real: 10.0
# Ejemplo 517 - Predicción: 10 - Valor real: 10.0
# Ejemplo 518 - Predicción: 10 - Valor real: 10.0
# Ejemplo 519 - Predicción: 10 - Valor real: 10.0
# Ejemplo 520 - Predicción: 10 - Valor real: 10.0
# Ejemplo 521 - Predicción: 10 - Valor real: 10.0
# Ejemplo 522 - Predicción: 10 - Valor real: 10.0
# Ejemplo 523 - Predicción: 10 - Valor real: 10.0
# Ejemplo 524 - Predicción: 10 - Valor real: 10.0
# Ejemplo 525 - Predicción: 10 - Valor real: 10.0
# Ejemplo 526 - Predicción: 10 - Valor real: 10.0
# Ejemplo 527 - Predicción: 10 - Valor real: 10.0
# Ejemplo 528 - Predicción: 21 - Valor real: 10.0
# Ejemplo 529 - Predicción: 10 - Valor real: 10.0
# Ejemplo 530 - Predicción: 10 - Valor real: 10.0
# Ejemplo 531 - Predicción: 10 - Valor real: 10.0
# Ejemplo 532 - Predicción: 10 - Valor real: 10.0
# Ejemplo 533 - Predicción: 10 - Valor real: 10.0
# Ejemplo 534 - Predicción: 10 - Valor real: 10.0
# Ejemplo 535 - Predicción: 10 - Valor real: 10.0
# Ejemplo 536 - Predicción: 10 - Valor real: 10.0
# Ejemplo 537 - Predicción: 10 - Valor real: 10.0
# Ejemplo 538 - Predicción: 10 - Valor real: 10.0
# Ejemplo 539 - Predicción: 10 - Valor real: 10.0
# Ejemplo 540 - Predicción: 10 - Valor real: 10.0
# Ejemplo 541 - Predicción: 10 - Valor real: 10.0
# Ejemplo 542 - Predicción: 10 - Valor real: 10.0
# Ejemplo 543 - Predicción: 10 - Valor real: 10.0
# Ejemplo 544 - Predicción: 10 - Valor real: 10.0
# Ejemplo 545 - Predicción: 10 - Valor real: 10.0
# Ejemplo 546 - Predicción: 10 - Valor real: 10.0
# Ejemplo 547 - Predicción: 10 - Valor real: 10.0
# Ejemplo 548 - Predicción: 10 - Valor real: 10.0
# Ejemplo 549 - Predicción: 10 - Valor real: 10.0
# Ejemplo 550 - Predicción: 10 - Valor real: 10.0
# Ejemplo 551 - Predicción: 10 - Valor real: 10.0
# Ejemplo 552 - Predicción: 10 - Valor real: 10.0
# Ejemplo 553 - Predicción: 10 - Valor real: 10.0
# Ejemplo 554 - Predicción: 21 - Valor real: 10.0
# Ejemplo 555 - Predicción: 10 - Valor real: 10.0
# Ejemplo 556 - Predicción: 10 - Valor real: 10.0
# Ejemplo 557 - Predicción: 10 - Valor real: 10.0
# Ejemplo 558 - Predicción: 10 - Valor real: 10.0
# Ejemplo 559 - Predicción: 10 - Valor real: 10.0
# Ejemplo 560 - Predicción: 10 - Valor real: 10.0
# Ejemplo 561 - Predicción: 11 - Valor real: 11.0
# Ejemplo 562 - Predicción: 11 - Valor real: 11.0
# Ejemplo 563 - Predicción: 11 - Valor real: 11.0
# Ejemplo 564 - Predicción: 11 - Valor real: 11.0
# Ejemplo 565 - Predicción: 11 - Valor real: 11.0
# Ejemplo 566 - Predicción: 11 - Valor real: 11.0
# Ejemplo 567 - Predicción: 11 - Valor real: 11.0
# Ejemplo 568 - Predicción: 11 - Valor real: 11.0
# Ejemplo 569 - Predicción: 11 - Valor real: 11.0
# Ejemplo 570 - Predicción: 11 - Valor real: 11.0
# Ejemplo 571 - Predicción: 11 - Valor real: 11.0
# Ejemplo 572 - Predicción: 11 - Valor real: 11.0
# Ejemplo 573 - Predicción: 11 - Valor real: 11.0
# Ejemplo 574 - Predicción: 11 - Valor real: 11.0
# Ejemplo 575 - Predicción: 11 - Valor real: 11.0
# Ejemplo 576 - Predicción: 11 - Valor real: 11.0
# Ejemplo 577 - Predicción: 11 - Valor real: 11.0
# Ejemplo 679 - Predicción: 12 - Valor real: 12.0
# Ejemplo 680 - Predicción: 12 - Valor real: 12.0
# Ejemplo 681 - Predicción: 12 - Valor real: 12.0
# Ejemplo 682 - Predicción: 12 - Valor real: 12.0
# Ejemplo 683 - Predicción: 12 - Valor real: 12.0
# Ejemplo 684 - Predicción: 12 - Valor real: 12.0
# Ejemplo 685 - Predicción: 12 - Valor real: 12.0
# Ejemplo 686 - Predicción: 12 - Valor real: 12.0
# Ejemplo 687 - Predicción: 12 - Valor real: 12.0
# Ejemplo 688 - Predicción: 12 - Valor real: 12.0
# Ejemplo 689 - Predicción: 12 - Valor real: 12.0
# Ejemplo 690 - Predicción: 12 - Valor real: 12.0
# Ejemplo 691 - Predicción: 12 - Valor real: 12.0
# Ejemplo 692 - Predicción: 12 - Valor real: 12.0
# Ejemplo 693 - Predicción: 12 - Valor real: 12.0
# Ejemplo 694 - Predicción: 12 - Valor real: 12.0
# Ejemplo 695 - Predicción: 12 - Valor real: 12.0
# Ejemplo 696 - Predicción: 12 - Valor real: 12.0
# Ejemplo 697 - Predicción: 12 - Valor real: 12.0
# Ejemplo 698 - Predicción: 12 - Valor real: 12.0
# Ejemplo 699 - Predicción: 12 - Valor real: 12.0
# Ejemplo 700 - Predicción: 12 - Valor real: 12.0
# Ejemplo 701 - Predicción: 12 - Valor real: 12.0
# Ejemplo 702 - Predicción: 12 - Valor real: 12.0
# Ejemplo 703 - Predicción: 12 - Valor real: 12.0
# Ejemplo 704 - Predicción: 12 - Valor real: 12.0
# Ejemplo 705 - Predicción: 12 - Valor real: 12.0
# Ejemplo 706 - Predicción: 12 - Valor real: 12.0
# Ejemplo 707 - Predicción: 12 - Valor real: 12.0
# Ejemplo 708 - Predicción: 12 - Valor real: 12.0
# Ejemplo 709 - Predicción: 12 - Valor real: 12.0
# Ejemplo 710 - Predicción: 12 - Valor real: 12.0
# Ejemplo 711 - Predicción: 12 - Valor real: 12.0
# Ejemplo 712 - Predicción: 12 - Valor real: 12.0
# Ejemplo 713 - Predicción: 12 - Valor real: 12.0
# Ejemplo 714 - Predicción: 12 - Valor real: 12.0
# Ejemplo 715 - Predicción: 12 - Valor real: 12.0
# Ejemplo 716 - Predicción: 12 - Valor real: 12.0
# Ejemplo 717 - Predicción: 12 - Valor real: 12.0
# Ejemplo 718 - Predicción: 12 - Valor real: 12.0
# Ejemplo 719 - Predicción: 12 - Valor real: 12.0
# Ejemplo 720 - Predicción: 12 - Valor real: 12.0
# Ejemplo 721 - Predicción: 12 - Valor real: 12.0
# Ejemplo 722 - Predicción: 12 - Valor real: 12.0
# Ejemplo 723 - Predicción: 12 - Valor real: 12.0
# Ejemplo 724 - Predicción: 12 - Valor real: 12.0
# Ejemplo 725 - Predicción: 12 - Valor real: 12.0
# Ejemplo 726 - Predicción: 12 - Valor real: 12.0
# Ejemplo 727 - Predicción: 12 - Valor real: 12.0
# Ejemplo 728 - Predicción: 12 - Valor real: 12.0
# Ejemplo 729 - Predicción: 12 - Valor real: 12.0
# Ejemplo 730 - Predicción: 12 - Valor real: 12.0
# Ejemplo 731 - Predicción: 12 - Valor real: 12.0
# Ejemplo 732 - Predicción: 12 - Valor real: 12.0
# Ejemplo 733 - Predicción: 12 - Valor real: 12.0
# Ejemplo 734 - Predicción: 12 - Valor real: 12.0
# Ejemplo 735 - Predicción: 12 - Valor real: 12.0
# Ejemplo 736 - Predicción: 12 - Valor real: 12.0
# Ejemplo 737 - Predicción: 12 - Valor real: 12.0
# Ejemplo 738 - Predicción: 12 - Valor real: 12.0
# Ejemplo 739 - Predicción: 12 - Valor real: 12.0
# Ejemplo 740 - Predicción: 12 - Valor real: 12.0
# Ejemplo 741 - Predicción: 12 - Valor real: 12.0
# Ejemplo 742 - Predicción: 12 - Valor real: 12.0
# Ejemplo 743 - Predicción: 12 - Valor real: 12.0
# Ejemplo 744 - Predicción: 12 - Valor real: 12.0
# Ejemplo 745 - Predicción: 12 - Valor real: 12.0
# Ejemplo 746 - Predicción: 12 - Valor real: 12.0
# Ejemplo 747 - Predicción: 12 - Valor real: 12.0
# Ejemplo 748 - Predicción: 12 - Valor real: 12.0
# Ejemplo 749 - Predicción: 12 - Valor real: 12.0
# Ejemplo 750 - Predicción: 12 - Valor real: 12.0
# Ejemplo 751 - Predicción: 12 - Valor real: 12.0
# Ejemplo 752 - Predicción: 12 - Valor real: 12.0
# Ejemplo 753 - Predicción: 12 - Valor real: 12.0
# Ejemplo 754 - Predicción: 12 - Valor real: 12.0
# Ejemplo 755 - Predicción: 12 - Valor real: 12.0
# Ejemplo 756 - Predicción: 12 - Valor real: 12.0
# Ejemplo 757 - Predicción: 12 - Valor real: 12.0
# Ejemplo 758 - Predicción: 12 - Valor real: 12.0
# Ejemplo 759 - Predicción: 12 - Valor real: 12.0
# Ejemplo 760 - Predicción: 12 - Valor real: 12.0
# Ejemplo 761 - Predicción: 13 - Valor real: 13.0
# Ejemplo 762 - Predicción: 13 - Valor real: 13.0
# Ejemplo 763 - Predicción: 13 - Valor real: 13.0
# Ejemplo 764 - Predicción: 13 - Valor real: 13.0
# Ejemplo 765 - Predicción: 13 - Valor real: 13.0
# Ejemplo 766 - Predicción: 13 - Valor real: 13.0
# Ejemplo 767 - Predicción: 13 - Valor real: 13.0
# Ejemplo 768 - Predicción: 13 - Valor real: 13.0
# Ejemplo 769 - Predicción: 13 - Valor real: 13.0
# Ejemplo 770 - Predicción: 13 - Valor real: 13.0
# Ejemplo 771 - Predicción: 13 - Valor real: 13.0
# Ejemplo 772 - Predicción: 13 - Valor real: 13.0
# Ejemplo 773 - Predicción: 13 - Valor real: 13.0
# Ejemplo 774 - Predicción: 13 - Valor real: 13.0
# Ejemplo 775 - Predicción: 13 - Valor real: 13.0
# Ejemplo 776 - Predicción: 13 - Valor real: 13.0
# Ejemplo 777 - Predicción: 13 - Valor real: 13.0
# Ejemplo 778 - Predicción: 13 - Valor real: 13.0
# Ejemplo 779 - Predicción: 13 - Valor real: 13.0
# Ejemplo 882 - Predicción: 14 - Valor real: 14.0
# Ejemplo 883 - Predicción: 14 - Valor real: 14.0
# Ejemplo 884 - Predicción: 14 - Valor real: 14.0
# Ejemplo 885 - Predicción: 14 - Valor real: 14.0
# Ejemplo 886 - Predicción: 14 - Valor real: 14.0
# Ejemplo 887 - Predicción: 14 - Valor real: 14.0
# Ejemplo 888 - Predicción: 14 - Valor real: 14.0
# Ejemplo 889 - Predicción: 14 - Valor real: 14.0
# Ejemplo 890 - Predicción: 14 - Valor real: 14.0
# Ejemplo 891 - Predicción: 14 - Valor real: 14.0
# Ejemplo 892 - Predicción: 14 - Valor real: 14.0
# Ejemplo 893 - Predicción: 14 - Valor real: 14.0
# Ejemplo 894 - Predicción: 14 - Valor real: 14.0
# Ejemplo 895 - Predicción: 14 - Valor real: 14.0
# Ejemplo 896 - Predicción: 14 - Valor real: 14.0
# Ejemplo 897 - Predicción: 14 - Valor real: 14.0
# Ejemplo 898 - Predicción: 14 - Valor real: 14.0
# Ejemplo 899 - Predicción: 14 - Valor real: 14.0
# Ejemplo 900 - Predicción: 14 - Valor real: 14.0
# Ejemplo 901 - Predicción: 14 - Valor real: 14.0
# Ejemplo 902 - Predicción: 14 - Valor real: 14.0
# Ejemplo 903 - Predicción: 14 - Valor real: 14.0
# Ejemplo 904 - Predicción: 14 - Valor real: 14.0
# Ejemplo 905 - Predicción: 14 - Valor real: 14.0
# Ejemplo 906 - Predicción: 14 - Valor real: 14.0
# Ejemplo 907 - Predicción: 14 - Valor real: 14.0
# Ejemplo 908 - Predicción: 14 - Valor real: 14.0
# Ejemplo 909 - Predicción: 14 - Valor real: 14.0
# Ejemplo 910 - Predicción: 14 - Valor real: 14.0
# Ejemplo 911 - Predicción: 14 - Valor real: 14.0
# Ejemplo 912 - Predicción: 14 - Valor real: 14.0
# Ejemplo 913 - Predicción: 14 - Valor real: 14.0
# Ejemplo 914 - Predicción: 14 - Valor real: 14.0
# Ejemplo 915 - Predicción: 14 - Valor real: 14.0
# Ejemplo 916 - Predicción: 14 - Valor real: 14.0
# Ejemplo 917 - Predicción: 14 - Valor real: 14.0
# Ejemplo 918 - Predicción: 14 - Valor real: 14.0
# Ejemplo 919 - Predicción: 14 - Valor real: 14.0
# Ejemplo 920 - Predicción: 14 - Valor real: 14.0
# Ejemplo 921 - Predicción: 14 - Valor real: 14.0
# Ejemplo 922 - Predicción: 14 - Valor real: 14.0
# Ejemplo 923 - Predicción: 14 - Valor real: 14.0
# Ejemplo 924 - Predicción: 14 - Valor real: 14.0
# Ejemplo 925 - Predicción: 14 - Valor real: 14.0
# Ejemplo 926 - Predicción: 14 - Valor real: 14.0
# Ejemplo 927 - Predicción: 14 - Valor real: 14.0
# Ejemplo 928 - Predicción: 14 - Valor real: 14.0
# Ejemplo 929 - Predicción: 14 - Valor real: 14.0
# Ejemplo 930 - Predicción: 14 - Valor real: 14.0
# Ejemplo 931 - Predicción: 14 - Valor real: 14.0
# Ejemplo 932 - Predicción: 14 - Valor real: 14.0
# Ejemplo 933 - Predicción: 14 - Valor real: 14.0
# Ejemplo 934 - Predicción: 14 - Valor real: 14.0
# Ejemplo 935 - Predicción: 14 - Valor real: 14.0
# Ejemplo 936 - Predicción: 14 - Valor real: 14.0
# Ejemplo 937 - Predicción: 14 - Valor real: 14.0
# Ejemplo 938 - Predicción: 14 - Valor real: 14.0
# Ejemplo 939 - Predicción: 14 - Valor real: 14.0
# Ejemplo 940 - Predicción: 14 - Valor real: 14.0
# Ejemplo 941 - Predicción: 14 - Valor real: 14.0
# Ejemplo 942 - Predicción: 14 - Valor real: 14.0
# Ejemplo 943 - Predicción: 14 - Valor real: 14.0
# Ejemplo 944 - Predicción: 14 - Valor real: 14.0
# Ejemplo 945 - Predicción: 14 - Valor real: 14.0
# Ejemplo 946 - Predicción: 14 - Valor real: 14.0
# Ejemplo 947 - Predicción: 14 - Valor real: 14.0
# Ejemplo 948 - Predicción: 14 - Valor real: 14.0
# Ejemplo 949 - Predicción: 14 - Valor real: 14.0
# Ejemplo 950 - Predicción: 14 - Valor real: 14.0
# Ejemplo 951 - Predicción: 14 - Valor real: 14.0
# Ejemplo 952 - Predicción: 14 - Valor real: 14.0
# Ejemplo 953 - Predicción: 14 - Valor real: 14.0
# Ejemplo 954 - Predicción: 14 - Valor real: 14.0
# Ejemplo 955 - Predicción: 14 - Valor real: 14.0
# Ejemplo 956 - Predicción: 14 - Valor real: 14.0
# Ejemplo 957 - Predicción: 14 - Valor real: 14.0
# Ejemplo 958 - Predicción: 14 - Valor real: 14.0
# Ejemplo 959 - Predicción: 14 - Valor real: 14.0
# Ejemplo 960 - Predicción: 14 - Valor real: 14.0
# Ejemplo 961 - Predicción: 15 - Valor real: 15.0
# Ejemplo 962 - Predicción: 15 - Valor real: 15.0
# Ejemplo 963 - Predicción: 15 - Valor real: 15.0
# Ejemplo 964 - Predicción: 15 - Valor real: 15.0
# Ejemplo 965 - Predicción: 15 - Valor real: 15.0
# Ejemplo 966 - Predicción: 15 - Valor real: 15.0
# Ejemplo 967 - Predicción: 15 - Valor real: 15.0
# Ejemplo 968 - Predicción: 15 - Valor real: 15.0
# Ejemplo 969 - Predicción: 15 - Valor real: 15.0
# Ejemplo 970 - Predicción: 15 - Valor real: 15.0
# Ejemplo 971 - Predicción: 15 - Valor real: 15.0
# Ejemplo 972 - Predicción: 15 - Valor real: 15.0
# Ejemplo 973 - Predicción: 15 - Valor real: 15.0
# Ejemplo 974 - Predicción: 15 - Valor real: 15.0
# Ejemplo 975 - Predicción: 15 - Valor real: 15.0
# Ejemplo 976 - Predicción: 15 - Valor real: 15.0
# Ejemplo 977 - Predicción: 15 - Valor real: 15.0
# Ejemplo 978 - Predicción: 15 - Valor real: 15.0
# Ejemplo 979 - Predicción: 15 - Valor real: 15.0
# Ejemplo 980 - Predicción: 15 - Valor real: 15.0
# Ejemplo 981 - Predicción: 15 - Valor real: 15.0
# Ejemplo 982 - Predicción: 15 - Valor real: 15.0
# Ejemplo 983 - Predicción: 15 - Valor real: 15.0
# Ejemplo 984 - Predicción: 15 - Valor real: 15.0
# Ejemplo 985 - Predicción: 15 - Valor real: 15.0
# Ejemplo 986 - Predicción: 15 - Valor real: 15.0
# Ejemplo 987 - Predicción: 15 - Valor real: 15.0
# Ejemplo 988 - Predicción: 15 - Valor real: 15.0
# Ejemplo 989 - Predicción: 15 - Valor real: 15.0
# Ejemplo 990 - Predicción: 15 - Valor real: 15.0
# Ejemplo 991 - Predicción: 15 - Valor real: 15.0
# Ejemplo 992 - Predicción: 15 - Valor real: 15.0
# Ejemplo 993 - Predicción: 15 - Valor real: 15.0
# Ejemplo 994 - Predicción: 15 - Valor real: 15.0
# Ejemplo 995 - Predicción: 15 - Valor real: 15.0
# Ejemplo 996 - Predicción: 15 - Valor real: 15.0
# Ejemplo 997 - Predicción: 15 - Valor real: 15.0
# Ejemplo 998 - Predicción: 15 - Valor real: 15.0
# Ejemplo 999 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1000 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1001 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1002 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1003 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1004 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1005 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1006 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1007 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1008 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1009 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1010 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1011 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1012 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1013 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1014 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1015 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1016 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1017 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1018 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1019 - Predicción: 15 - Valor real: 15.0
# Ejemplo 1020 - Predicción: 15 - Valor real: 15.0
# ...
# Ejemplo 1434 - Predicción: 19 - Valor real: 19.0
# Ejemplo 1435 - Predicción: 19 - Valor real: 19.0
# Ejemplo 1436 - Predicción: 19 - Valor real: 19.0
# Ejemplo 1437 - Predicción: 19 - Valor real: 19.0
# Ejemplo 1438 - Predicción: 19 - Valor real: 19.0
# Ejemplo 1439 - Predicción: 19 - Valor real: 19.0
# Ejemplo 1440 - Predicción: 19 - Valor real: 19.0
# Ejemplo 1441 - Predicción: 19 - Valor real: 19.0
# Ejemplo 1442 - Predicción: 19 - Valor real: 19.0
# Ejemplo 1443 - Predicción: 19 - Valor real: 19.0
# Ejemplo 1444 - Predicción: 19 - Valor real: 19.0
